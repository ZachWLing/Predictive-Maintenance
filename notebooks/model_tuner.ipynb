# %%
import math
import pickle
import keras_tuner
import numpy as np
import librosa as lr
import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
def import_pkl(path):
    data = []
    with (open(path, 'rb')) as openfile:
        while True:
            try:
                data = pickle.load(openfile)
            except EOFError:
                break
    return data['X_train'], data['y_train'], data['X_test'], data['y_test']

# %%
train00_X, train00_y, test00_X, test00_y = import_pkl('../data/id_00_raw.pkl')
train02_X, train02_y, test02_X, test02_y = import_pkl('../data/id_02_raw.pkl')
train04_X, train04_y, test04_X, test04_y = import_pkl('../data/id_04_raw.pkl')
train06_X, train06_y, test06_X, test06_y = import_pkl('../data/id_06_raw.pkl')

# %%
class MyHyperModel(keras_tuner.HyperModel):
    
    def __init__(self, min_delta):
        self.input_shape_x = 0
        self.input_shape_y = 0
        self.min_delta = min_delta
    
    def build(self, hp):
        
        n_mels = hp.Choice('n_mels', [128, 256, 512])
        hop_length = hp.Choice('hop_length', [128, 256, 512])

        self.input_shape_x = n_mels
        self.input_shape_y = hop_length
               
        inputLayer = Input(shape = (self.input_shape_x, math.ceil((22050 * 10) / self.input_shape_y)))
        h = Flatten()(inputLayer)
        h = Dense(units = hp.Choice('layer 1', [64, 128, 256]), activation = 'relu')(h)
        h = Dense(units = hp.Choice('layer 2', [64, 32, 16]), activation = 'relu')(h)
        h = Dense(units = hp.Choice('layer 3', [4, 8]), activation = 'relu')(h)
        h = Dense(units = hp.Choice('layer 4', [64, 32, 16]), activation = 'relu')(h)
        h = Dense(units = hp.Choice('layer 5', [64, 128, 256]), activation = 'relu')(h)
        h = Dense(self.input_shape_x * math.ceil((22050 * 10) / self.input_shape_y), activation = None)(h)
        h = Reshape((self.input_shape_x, math.ceil((22050 * 10) / self.input_shape_y)))(h)
                  
        Model(inputs = inputLayer, outputs = h).compile(loss = 'mean_squared_error', metrics = ['mse'])

        return Model(inputs = inputLayer, outputs = h)

    def fit(self, hp, model, train, validation, callbacks = None, **kwargs):
        
        def convert_to_melspectrogram(audio_files, sr, n_fft, hop_length, n_mels):
            audio_mel = lr.feature.melspectrogram(y = audio_files[0], sr = sr, n_fft = n_fft, hop_length = hop_length, n_mels = n_mels)
            audio_mel_dbd = lr.amplitude_to_db(abs(audio_mel), ref = np.max)
            shape_0 = audio_mel_dbd.shape[0]
            shape_1 = audio_mel_dbd.shape[1]
            audio_mel_dbd = np.reshape(audio_mel_dbd, [1, shape_0, shape_1])

            for file in audio_files[1:10]:
                audio_mel_temp = lr.feature.melspectrogram(y = file, sr = sr, n_fft = n_fft, hop_length = hop_length, n_mels = n_mels)
                audio_mel_dbd_temp = lr.amplitude_to_db(abs(audio_mel_temp), ref = np.max)
                audio_mel_dbd = np.vstack([audio_mel_dbd, np.reshape(audio_mel_dbd_temp, [1, shape_0, shape_1])])
            return audio_mel_dbd

        train_ds = convert_to_melspectrogram(train, 22050, 1024, self.input_shape_y, self.input_shape_x)
                            
        # Define the optimizer.
        optimizer = keras.optimizers.Adam(hp.Float('learning_rate', 1e-4, 1e-2, sampling = 'log', default = 1e-3))
        loss_fn = keras.losses.MeanSquaredError(reduction = 'auto', name = 'mean_squared_error')

        # The metric to track validation loss.
        epoch_loss_metric = keras.metrics.Mean()

        # Function to run the train step.
        @tf.function
        def run_train_step(train):
            with tf.GradientTape() as tape:
                logits = model(train)
                loss = loss_fn(train, logits)
                # Add any regularization losses.
                if model.losses:
                    loss +=  tf.math.add_n(model.losses)
            gradients = tape.gradient(loss, model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, model.trainable_variables))

        # Function to run the validation step.
        @tf.function
        def run_val_step(validation):
            logits = model(validation)
            loss = loss_fn(validation, logits)
            # Update the metric.
            epoch_loss_metric.update_state(loss)

        # Assign the model to the callbacks.
        for callback in callbacks:
            callback.model = model

        # Record the best validation loss value
        best_epoch_loss = float("inf")

        # The custom training loop.
#         epochs = hp.Choice('epochs', [25, 50, 75])
        for epoch in range(5):
            print(f"Epoch: {epoch}")

            # Iterate the training data to run the training step.
            for sample in train_ds:
                run_train_step(sample.reshape(1, sample.shape[0], sample.shape[1]))

            # Iterate the validation data to run the validation step.
            for sample in train_ds:
                run_val_step(sample.reshape(1, sample.shape[0], sample.shape[1]))

            # Calling the callbacks after epoch.
            epoch_loss = float(epoch_loss_metric.result().numpy())
            for callback in callbacks:
                # The "val_loss" is the objective passed to the tuner.
                callback.on_epoch_end(epoch, logs = {"val_loss": epoch_loss})
            epoch_loss_metric.reset_states()

            print(f"Epoch loss: {epoch_loss}")
            
            if best_epoch_loss <= (epoch_loss + self.min_delta):
                break
            else:
                best_epoch_loss = min(best_epoch_loss, epoch_loss)

        # Return the evaluation metric value.
        return best_epoch_loss

# %%
tuner = keras_tuner.RandomSearch(
    objective = keras_tuner.Objective('val_loss', 'min'),
    seed = 41,
    max_trials = 5,
    hypermodel = MyHyperModel(min_delta = 0),
    directory = '../model/results',
    project_name = 'custom_training',
    overwrite = True,
)

# %%
tuner.search(train = train00_X, validation = train00_X)
# Out:
# Trial 2 Complete [00h 00m 57s]
# val_loss: 324.7400207519531
#
# Best val_loss So Far: 324.7400207519531
# Total elapsed time: 00h 01m 13s
#
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 512               |256               |n_mels
# 128               |128               |hop_length
# 128               |128               |layer 1
# 64                |64                |layer 2
# 4                 |8                 |layer 3
# 32                |32                |layer 4
# 256               |256               |layer 5
# 0.00077674        |0.00015159        |learning_rate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 tuner.search(train = train00_X, validation = train00_X)
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras_tuner\engine\base_tuner.py:230, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     227         continue
#     229     self.on_trial_begin(trial)
# --> 230     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     231     self.on_trial_end(trial)
#     232 self.on_search_end()
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras_tuner\engine\base_tuner.py:270, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     268 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     269     try:
# --> 270         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     271         trial.status = trial_module.TrialStatus.COMPLETED
#     272         return
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras_tuner\engine\base_tuner.py:235, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     234 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 235     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     236     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     237         self.oracle.objective.name
#     238     ):
#     239         # The oracle is updated by calling `self.oracle.update_trial()` in
#     240         # `Tuner.run_trial()`. For backward compatibility, we support this
#     241         # use case. No further action needed in this case.
#     242         warnings.warn(
#     243             "The use case of calling "
#     244             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     250             stacklevel=2,
#     251         )
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras_tuner\engine\tuner.py:287, in Tuner.run_trial(self, trial, *args, **kwargs)
#     285     callbacks.append(model_checkpoint)
#     286     copied_kwargs["callbacks"] = callbacks
# --> 287     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     289     histories.append(obj_value)
#     290 return histories
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras_tuner\engine\tuner.py:213, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     195 """For AutoKeras to override.
#     196
#     197 DO NOT REMOVE this function. AutoKeras overrides the function to tune
#    (...)
#     210     The fit history.
#     211 """
#     212 hp = trial.hyperparameters
# --> 213 model = self._try_build(hp)
#     214 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     215 tuner_utils.validate_trial_results(
#     216     results, self.oracle.objective, "HyperModel.fit()"
#     217 )
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras_tuner\engine\tuner.py:155, in Tuner._try_build(self, hp)
#     152 keras.backend.clear_session()
#     153 gc.collect()
# --> 155 model = self._build_hypermodel(hp)
#     156 # Stop if `build()` does not return a valid model.
#     157 if not isinstance(model, keras.models.Model):
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras_tuner\engine\tuner.py:146, in Tuner._build_hypermodel(self, hp)
#     144 def _build_hypermodel(self, hp):
#     145     with maybe_distribute(self.distribution_strategy):
# --> 146         model = self.hypermodel.build(hp)
#     147         self._override_compile_args(model)
#     148         return model
#
# Cell In[29], line 24, in MyHyperModel.build(self, hp)
#      22 h = Dense(units = hp.Choice('layer 5', [64, 128, 256]), activation = 'relu')(h)
#      23 h = Dense(self.input_shape_x * math.ceil((22050 * 10) / self.input_shape_y), activation = None)(h)
# ---> 24 h = Reshape((self.input_shape_x, math.ceil((22050 * 10) / self.input_shape_y)))(h)
#      26 Model(inputs = inputLayer, outputs = h).compile(loss = 'mean_squared_error', metrics = ['mse'])
#      28 return Model(inputs = inputLayer, outputs = h)
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras\src\engine\base_layer.py:1063, in Layer.__call__(self, *args, **kwargs)
#    1055 # Functional Model construction mode is invoked when `Layer`s are called
#    1056 # on symbolic `KerasTensor`s, i.e.:
#    1057 # >> inputs = tf.keras.Input(10)
#    1058 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#    1059 # >> model = tf.keras.Model(inputs, outputs)
#    1060 if _in_functional_construction_mode(
#    1061     self, inputs, args, kwargs, input_list
#    1062 ):
# -> 1063     return self._functional_construction_call(
#    1064         inputs, args, kwargs, input_list
#    1065     )
#    1067 # Maintains info about the `Layer.call` stack.
#    1068 call_context = base_layer_utils.call_context()
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras\src\engine\base_layer.py:2594, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    2588 with call_context.enter(
#    2589     layer=self, inputs=inputs, build_graph=True, training=training_value
#    2590 ):
#    2591     # Check input assumptions set after layer building, e.g. input
#    2592     # shape.
#    2593     try:
# -> 2594         outputs = self._keras_tensor_symbolic_call(
#    2595             inputs, input_masks, args, kwargs
#    2596         )
#    2597     except TypeError as e:
#    2598         if "DictWrapper" in str(e):
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras\src\engine\base_layer.py:2440, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#    2436     return tf.nest.map_structure(
#    2437         keras_tensor.KerasTensor, output_signature
#    2438     )
#    2439 else:
# -> 2440     return self._infer_output_signature(
#    2441         inputs, args, kwargs, input_masks
#    2442     )
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras\src\engine\base_layer.py:2499, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#    2497         self._maybe_build(inputs)
#    2498         inputs = self._maybe_cast_inputs(inputs)
# -> 2499         outputs = call_fn(inputs, *args, **kwargs)
#    2501     self._handle_activity_regularization(inputs, outputs)
#    2502 self._set_mask_metadata(
#    2503     inputs, outputs, input_masks, build_graph=False
#    2504 )
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras\src\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~\Anaconda3\envs\capstone\lib\site-packages\keras\src\layers\reshaping\reshape.py:137, in Reshape.call(self, inputs)
#     136 def call(self, inputs):
# --> 137     result = tf.reshape(inputs, (tf.shape(inputs)[0],) + self.target_shape)
#     138     if not tf.executing_eagerly():
#     139         # Set the static shape for the result since it might lost during
#     140         # array_ops reshape, eg, some `None` dim in the result could be
#     141         # inferred.
#     142         result.set_shape(self.compute_output_shape(inputs.shape))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\array_ops.py:1104, in _slice_helper(tensor, slice_spec, var)
#    1096 with ops.name_scope(
#    1097     None,
#    1098     "strided_slice", [tensor] + begin + end + strides,
#    1099     skip_on_eager=False) as name:
#    1100   if begin:
#    1101     packed_begin, packed_end, packed_strides = (
#    1102         array_ops_stack.stack(begin),
#    1103         array_ops_stack.stack(end),
# -> 1104         array_ops_stack.stack(strides))
#    1105     # TODO(mdan): Instead of implicitly casting, it's better to enforce the
#    1106     # same dtypes.
#    1107     if (packed_begin.dtype == dtypes.int64 or
#    1108         packed_end.dtype == dtypes.int64 or
#    1109         packed_strides.dtype == dtypes.int64):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\ops\array_ops_stack.py:74, in stack(values, axis, name)
#      71 if axis == 0:
#      72   try:
#      73     # If the input is a constant list, it can be converted to a constant op
# ---> 74     return ops.convert_to_tensor(values, name=name)
#      75   except (TypeError, ValueError, NotImplementedError):
#      76     pass  # Input list contains non-constant tensors
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py:1369, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1367 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#    1368 preferred_dtype = preferred_dtype or dtype_hint
# -> 1369 return tensor_conversion_registry.convert(
#    1370     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#    1371 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\constant_op.py:327, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     324 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     325                                          as_ref=False):
#     326   _ = as_ref
# --> 327   return constant(v, dtype=dtype, name=name)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\constant_op.py:266, in constant(value, dtype, shape, name)
#     169 @tf_export("constant", v1=[])
#     170 def constant(value, dtype=None, shape=None, name="Const"):
#     171   """Creates a constant tensor from a tensor-like object.
#     172
#     173   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     264     ValueError: if called on a symbolic tensor.
#     265   """
# --> 266   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     267                         allow_broadcast=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\constant_op.py:280, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     278   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 280 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     281     value, dtype, shape, name, verify_shape, allow_broadcast
#     282 )
#     283 return const_tensor
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py:939, in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     937 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     938 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 939 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     940     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     942 if op_callbacks.should_invoke_op_callbacks():
#     943   # TODO(b/147670703): Once the special-op creation code paths
#     944   # are unified. Remove this `if` block.
#     945   callback_outputs = op_callbacks.invoke_op_callbacks(
#     946       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py:3307, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3304 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3305 # Session.run call cannot occur between creating and mutating the op.
#    3306 with self._mutation_lock():
# -> 3307   ret = Operation.from_node_def(
#    3308       node_def,
#    3309       self,
#    3310       inputs=inputs,
#    3311       output_types=dtypes,
#    3312       control_inputs=control_inputs,
#    3313       input_types=input_types,
#    3314       original_op=self._default_original_op,
#    3315       op_def=op_def,
#    3316   )
#    3317   self._create_op_helper(ret, compute_device=compute_device)
#    3318 return ret
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py:1815, in Operation.from_node_def(***failed resolving arguments***)
#    1812     control_input_ops.append(control_op)
#    1814 # Initialize c_op from node_def and other inputs
# -> 1815 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1816 self = Operation(c_op, SymbolicTensor)
#    1817 self._init(g)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\framework\ops.py:1674, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1670   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1671                                          serialized)
#    1673 try:
# -> 1674   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1675 except errors.InvalidArgumentError as e:
#    1676   # Convert to ValueError for backwards compatibility.
#    1677   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
best_hps = tuner.get_best_hyperparameters()[0]
print(best_hps.values)

best_model = tuner.get_best_models()[0]
print(best_model.summary())
